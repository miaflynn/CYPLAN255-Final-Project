# %% [markdown]
# <a href="https://colab.research.google.com/github/miaflynn/CYPLAN255-Final-Project/blob/main/notebooks/02d_processing_naics_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Importing

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os


from google.colab import drive
drive.mount('/content/drive')

#uncomment on first run
# !wget https://raw.githubusercontent.com/miaflynn/CYPLAN255-Final-Project/main/src/functions.py
# import functions as fx

import importlib
importlib.reload(fx)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <module 'functions' from '/content/functions.py'>

# %% [markdown]
# ##Reading in file

# %%
#gdf of opening dates after 2016 concatenated with gdf of closing dates after 2016
gdf_open_close = gpd.read_file("/content/drive/MyDrive/C255_final_project/cleaned/open_close_after_2016.geojson")

# %% [markdown]
# ##Reading in census tracts and block groups

# %%
sf_tracts = gpd.read_file('/content/drive/MyDrive/C255_final_project/cleaned/sf_tracts.geojson')

sf_block_grp = gpd.read_file('/content/drive/MyDrive/C255_final_project/cleaned/sf_block_grp.geojson')

sf_neigh = gpd.read_file('/content/drive/MyDrive/C255_final_project/cleaned/sf_neighborhoods.geojson')

# %%
open_close_tracts_gdf = fx.group_points_by_poly_naics_year(
    gdf_open_close,
    sf_neigh,
    id_col='neighborhood'
)

open_close_tracts_gdf
#open_close_tracts_gdf.to_file('/content/drive/MyDrive/C255_final_project/cleaned/open_close_neighs.geojson', driver='GeoJSON')
# Out:
#                neighborhood  \
# 0          Western Addition
# 1          Western Addition
# 2          Western Addition
# 3          Western Addition
# 4          Western Addition
# ...                     ...
# 5784  Bayview Hunters Point
# 5785  Bayview Hunters Point
# 5786  Bayview Hunters Point
# 5787  Bayview Hunters Point
# 5788  Bayview Hunters Point
#
#                                                geometry naics_code  year  \
# 0     MULTIPOLYGON (((-122.42144 37.78557, -122.4213...  5210-5239  2016
# 1     MULTIPOLYGON (((-122.42144 37.78557, -122.4213...  8100-8139  2016
# 2     MULTIPOLYGON (((-122.42144 37.78557, -122.4213...  4200-4299  2016
# 3     MULTIPOLYGON (((-122.42144 37.78557, -122.4213...  2300-2399  2016
# 4     MULTIPOLYGON (((-122.42144 37.78557, -122.4213...  2200-2299  2016
# ...                                                 ...        ...   ...
# 5784  MULTIPOLYGON (((-122.38158 37.75307, -122.3815...  5210-5239  2025
# 5785  MULTIPOLYGON (((-122.38158 37.75307, -122.3815...  5100-5199  2025
# 5786  MULTIPOLYGON (((-122.38158 37.75307, -122.3815...  4800-4999  2025
# 5787  MULTIPOLYGON (((-122.38158 37.75307, -122.3815...  4400-4599  2025
# 5788  MULTIPOLYGON (((-122.38158 37.75307, -122.3815...  4200-4299  2025
#
#       closed  opened
# 0        3.0     6.0
# 1        3.0     4.0
# 2        3.0     8.0
# 3        3.0     3.0
# 4        1.0     2.0
# ...      ...     ...
# 5784     2.0     0.0
# 5785     2.0     1.0
# 5786    11.0     8.0
# 5787    38.0    17.0
# 5788     7.0     5.0
#
# [5789 rows x 6 columns]
